# %% [markdown]
# # Grundlagen der Python Programmierung
# Was kommt? Das wichtigste im Schnelldurchlauf:
# * Strukturieren mit Einrücken - Funtkion und Optic!
# * Datentypen und Variablen - damit wir wissen was wir speichern!
# * Operatoren - etwas "tun"
# * Listen, Mengen, Dictionaries - wenn vieles zusammenkommen soll!
# * Input von Aussen
# * Bedingungen stellen!
# * Wiederholen lassen!
#
# Version 1.000
# Last Update: 2024-09-11
#
# ## Strukturierung
# Bitte die Quelle berücksichtigen/durcharbeiten
# Quelle: https://www.python-kurs.eu/python3_bloecke.php
#
# Python wählt einen pragmatischen Ansatz - statt einrücke nur für die "optic" zu berücksichtigen übernimmt es die Funktion von Klammerstrukturen - das spart Zeit und zwingt einen zugleich "schön lesbaren" Code zu schreiben.

# %% [markdown]
# Das folgende Programm muss nicht mathematisch verstanden werden, es soll nur zeigen wie man einrücken kann um "Strucktur" und bedeutung zu geben.  Es berechnet die Pyxtagoreischen Tripel also die Zahlen wie im folgennden Dreieck für die gilt 3² + 4² = 5² (9+16=25)
# ![image.png](attachment:image.png)
# Quelle und für die die es wissen wollen: https://de.wikipedia.org/wiki/Pythagoreisches_Tripel

# %%
# Funtkion für die Pythagorean triples
from math import sqrt

n = input("Maximal Number? ")
print ("Deine eingabe war: " + n)
n = int(n)+1
for a in range(1,n):
    for b in range(a,n):
        c_square = a**2 + b**2
        c = int(sqrt(c_square))
        if ((c_square - c**2) == 0):
            print(a, b, c)

# %% [markdown]
# Die folgende Grafik versucht dies zu Visualisieren.
# Wir starten im "grünen" Rechteck und laufen von oben nach unten durch.
# In Zeile 7 wird nun eine "Schleife" durch das wort for aufgebaut - als was diese schleife wiederholen soll muss entsprechend eingerückt werden also ab Zeile 8 im lilanen Kästchen.
# In Zeile 8 steht direkt wieder eine Schleife man darf also verschachteln - alles was diese ausführen soll liegt nun im eingerückten Bereich darunter (gelbes Rechteck).
# In Zeile 11 wird nun im gelben Rechteck noch etwas geprüft - eine Fall Unterscheidung alles was darint bearbeitet werden soll wird wieder eingerückt und ist im roten Rechteck ( print in Zeile 12).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Datentypen und Variablen
#
# Bitte hierzu die Quelle berücksichtigen und bearbeiten: https://www.python-kurs.eu/python3_variablen.php
#
# Kurzgefasst:
# Grundsätzlich unterscheidet man beim Programmieren wie man die 0 'en und 1 'en interpretieren soll, die eine Maschine eben speichern/verarbeiten kann: stehen diese für einen Buchstaben oder Zahlen? Ganzzahlen oder Kommazahlen? Dies nennt man Datentypen.
# In vielen Sprachen muss dies Expliziet angegeben werden, in Python ist man etwas flexibler, muss aber auch hier und da den Datentyp erzwingen.
# siehe hierzu den Abschnitt im Link:
# ### Benutzen von Variablen

# %%
#Ganz einfaches Programm

i = 42          # Typ wird implizit auf Integer gesetzt
print(i)
print(i + i)    #Addiere ich nun wird mathematisch addiert
i = 41 + 0.11   # Typ wird in float geändert
print(i)
i = "fünfzig"   # Jetzt ist es ein string
print(i)
print(i + i)    # Addiere ich hier wird "konkateniert" also text an text gehangen

# %% [markdown]
# ### Variablen sind Objektreferenzen
# (siehe gleiche Quelle)
# Ohne es zu kompliziert zu machen, Wenn wir etwas "speichern" wollen haben wir eine Variable. Diese zeigt quasi in den Speicher des Rechners wo diese nun den Wert abgelegt hat. Der Wert liegt wie im Bild nicht in der Variablen, sondern diese zeigt nur die Adresse an wo man den Wert finden kann.

# %%
x = 42  # bekommt neuen Wert und zeigt darauf
y = x   # y und x zeigen nun auf den gleichen Wert im Speicher
y = 78  # y bekommt einen neuen Wert, x zeigt weiter auf den alten
print (x)
print (y)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Quelle https://www.python-kurs.eu/python3_variablen.php

# %% [markdown]
# Expermientieren Sie mit den "Referenzen"!

# %%
#Üben Variablen/Referenzen
#!!!!Definitiv nochmal im Kapitel anschauen, 
# wie sich Referenzen/Variablen verhalten!!!

# %% [markdown]
# ### Variablen "schnell Blick"
# Schnelle ein Beispiel der typischen Typen ;-)

# %%
# Python kennt die folgenden eingebauten (built-in) Datentypen für Zahlen:

# Ganzzahl (Integer)
x = 4321
print(x)
print("Ganzzahl: " + str(x) )
# Eine Oktalzahl markiert man, indem man ein "0o", d.h. Ziffer Null gefolgt von einem kleinen "o" (oder einem großen "O"), der Zahl voranstellt:
x = 0o11
print(x)
print("Oktal: " + str(x) )

# Eine Hexadezimalzahl (Hexzahl) markiert man mit einem vorangestellten "0x" oder "0X":
x = 0x1A
print(x)
print("Hexadezimalzahl: " + str(x) )

#Literale als Binärzahl lassen sich ähnlich leicht darstellen. Die führende Null wird nun von einem kleinen "b" oder großen "B" gefolgt:
x = 0b101010
print(x)
print ("Hexadezimalzahl: " + str(x))

#Mit den Funktionen hex, bin, oct kann man eine Integer-Zahl in einen String wandeln, der der Stringdarstellung der Zahl in der entsprechenden Basis entspricht:
x = hex(19)
print(x)
print ("hex: " + str(x) )
type(x)

# Binär
x = bin(65)
print(x)
print ("bin: " + str(x) )
type(x)

x = oct(65)
print(x)
print ("oct: " + str(x) )
type(x)
print ("Oct umwandeln: " +  oct(0b101101)) 

#In Python2 wurde noch zwischen "int" und "long int" unterschieden. In Python3 gibt es nur noch "Integer", die beliebig lang sein können:

x = 787366098712738903245678234782358292837498729182728
print(x)
print("int: " + str(x))
print(x)
print ("int ganz long: " + str(x * x * x))

# %% [markdown]
# Schaune sie sich noch die weiteren Beispiel im Link oben an (Division, String ) und geben Sie die Beispiele hier ein als Python Code

# %%
#Ganzzahlige Division 
# / aus int wird float 
# // int bleibt int
# % modulo = Rest von //
i = 10
j = 3
k = i/j
print ("Typ von i: " + str(type(i) )+ "\n" + "Typ von j: " + str(type(j)) + "\n" + "Typ von k: " + str(type(k)))
l = i//j
print ("\nTyp von i: " + str(type(i) )+ "\n" + "Typ von j: " + str(type(j)) + "\n" + "Typ von l: " + str(type(l)))
m = i%j
print ("\nTyp von i: " + str(type(i) ) + "\n" + "Typ von j: " + str(type(j)) + "\n" + "Typ von m: " + str(type(m)))

#String-Interna
string = "Hallo Welt"
#Eckige Klammern für "Index eines Elements"
print(string[0])
print(string[6])
#Da bei Null angefangen wird ist der letzte Index die Länge -1, len() bestimmung der Länge
last_index = len(string) -1 
print(string[last_index])
#kürzere Option: 
#Index von hinten mit negativem Vorzeichen zählbar, dabei ist -1 die letzte Stelle 
print(string[-1]) 

#Funktionen 
#Concat = Verbinden
print("Hallo" + " du da")

#Wiederholung
print("Hallo " * 3)

#Indexing (siehe oben) = Aufrufen per Index

#Slicing = einzelne Ausschnitte raus nehmen
print(string[2:9])

#Verschiedene Anführungszeichen möglich z.B. 'Hallo' oder "Hallo" oder """Hallo"""

#Besonderheiten
#string1 is string2 funktioniert nur bei "normalen Zeichen"
#hierbei sind aber Sonderzeichen und Blanks/Leerzeichen nicht verwertbar
#string1 == string2 dagegen funktioniert
#verschiedene Escape- oder Fluchtzeichen für "Textformatierung"
#es ist möglich die Codierung von Strings zu ändern z.B. zu Byte-Strings (UTF-8)

# %% [markdown]
# ## Operatoren
# In jeder Programmiersprache, wie auch im Taschenrechner, gibt es Operatoren dennen gewisse Funktionen zugewiesen sind, hier sollte man sich einen Überblick verschaffen und wissen was es gibt, damit man ggf. später nachschauen und sich etwas Arbeit sparen kann. Klassiker sind +-*/, etwas ungewöhnlicher aber auch schon oben gesehen ** für einen Exponenten also x² wäre dann x**2.
# Eine Übersicht finden Sie hier, gerne in Python probieren!:
# https://www.python-kurs.eu/python3_operatoren.php

# %%
# Eingabe und diese als int "speichern" - sonst ist die Eingabe die Zeichenkette nicht die Zahl 5
x = int( input("Wert für x in x²:") )
# Nun kann ich x² Rechnen, wenn kein Text dabei kommt auch ohne str direkt ausgeben
print(x**2)

# %% [markdown]
# Schauen Sie sich die Operatoren an un Experimientieren Sie!

# %%
# Üben Operatoren
# +, -, *, %, /, // (Operatoren)
# -x, +x (Vorzeichen)
# ~x (Bitweise Not)
# ** Potenz
# or, and, not (Boolsch oder, und, nicht)
# in ("Element von")
# <, <=, >, >=, !=, == (Vergleichsoperator)
#|, &, ^ (Bitweise oder, und, xor)
#<<, >> (Shiftoperatoren)

# %% [markdown]
# ## Listen oder viele von etwas (auch ein Datentyp)
# Quelle: https://www.python-kurs.eu/python3_sequentielle_datentypen.php
# Häufig will man nicht nur "ein" Wert speichern, sondern viele. Einfaches beispiel wäre ein Text, der aus vielen Buchstaben besteht und in Python eben auch ähnlich genutzt werden kann wie jede andere Liste!

# %%
text = "Hey hier sind viele Buchstaben oder Zahlen wie 5 als Zeichenkette drin!"
print(text[0], text[11], text[-1]) 

# Eine Liste "erstellen":
lst1 = ["Wien", "London", "Paris", "Berlin", "Zürich", "Hamburg"]
lst2 = [1, 2, 3, 10, 20, 30]

# Zugriff auf ein Element einer Liste:
print(lst1[0])
print(lst1[2])
print(lst1[-1])  

print(lst2[0])
print(lst2[2])
print(lst2[-1])

# %% [markdown]
# Schauen sie sich im Link die Listennotation und Beispiele an und versuchen Sie diese!
# Auch Zugriff, Unterlisten, Verändern, Tupel (statt [] hier () nutzen), Slicing, Länge, Verketten, Überprüfen ob enthalten, usw.

# %%
# Üben von Listen und Co.
#Bytes

s = "Glückliche Fügung"
s_bytes = s.encode('utf-8') 
print(s_bytes) #kann keine Sonderzeichen, da in utf-8 nur ASCII enthalten

#Python-Listen (Vergleichbar mit C, C++, Java -Arrays, nur um einiges flexibler)
#Listenelemente müssen nicht vom gleichen Typ sein
#Listen haben eine fice Reihenfolge/Indizevergabe
#Listen werden mit "[]"" umrahmt, Elemnte mit "," getrennt und
#mit [[],[],[]] lassen sich Unterlisten bauen
#Zugriff auf Listenelemente mit Indizes, wie auch bei Strings
#Elemente von Unterlisten aufrufen: Listenname[Hauptindex][Unterindex]

#Beispiel Komplexe Liste
komplexe_Liste = [["a", ["b", ["c", "x"]]]]
komplexe_Liste = [["a", ["b", ["c", "x"]]], 42]
print(komplexe_Liste[0][1])
print(komplexe_Liste[0][1][1][0])

#Listen ändern
#...

#Tupel
#unveränderliche Listen 
#Elemente in () statt []
#Können als Schlüssel in Wörterbüchern verwendet werden, weil es sichere Kombinationen sind

#Slicen wie Strings
#[:5] bis 5
#[5:] ab 5
#[1:-5] von 1 bis 5.Element von hinten
#geht auch mit [Anfang:Ende:Schrittgröße]

#Länge weiterhin mit len()

#Verkettung von Sequenzen
#Listen = Liste1 + Liste2
#Liste1 += Liste2 
#Listen == Liste1

#Auf Element prüfen
#"Elementwert" (not) in "Listenname" -> Boolsches Ergebnis

#Wiederholungen (wie String)
#Liste = Liste * Anzahl
#Liste *= Anzahl
#!!!!!Aufpassen, da hier Unterlisten entstehen können, 
# die auch bei Veränderungen in den Unterelementen immer zueinander identlisch bleiben,
# da Python die Ursprungsliste nur mehrfach "abruft" und die Änderung eigentlich in ihr stattfindet

# %% [markdown]
# ### Mengen versus Listen
# Statt geordnet, geht es auch ungeordnet und einmalig: Mengen! Hierzu findet man dann angaben in []  zur Erinnerung [] Listen und () Tupel - kann man Natürlich auch kombinieren, mehr infos unter:
# https://www.python-kurs.eu/python3_sets_mengen.php

# %%
# Eine Menge von Tupeln 
# (geht nicht mit ['Frankfurt',0.7],... 
# das wäre veränderlich und mögen die Mengen nicht)
staedte = {('Frankfurt', 0.7), ('Stuttgart', 0.6), ('Hamburg', 1.75), ('Berlin', 3.42), ('Köln', 1.03), ('München', 1.41)}
print(staedte)
print( 'Trier' in staedte )
print( 'München' in staedte )
print( ('Berlin', 3.42)  in staedte ) 
#Tupel sind für Python geschlossene Elemente beim Vergleich
for s in staedte: #Für alle Elemente in der Menge (Reihenfolge aber im Prinzip random)
    print(s[0])

# %% [markdown]
# Schauen und Üben Sie das Arbeiten mit Mengen!

# %%
# Üben mit Mengen
# mit set(Liste) lässt sich aus einer Liste eine Menge erstellen
# mit list(Menge) lässt sich aus einer Menge eine Liste erstellen
# frozenset(Liste) wird eine unveränderliche Menge, 
# also im Prinzip was Tupel bei Liste ist frozenset bei Menge

# Funktionen auf Sets

    # Menge.add(Element) gibt die Möglichkeit Dinge hinzuzufügen
    # Menge.clear() = leert die Menge
    # Menge_Kopie = Menge.copy()
        # Menge_Kopie = Menge würde nur einen Pointer auf Menge erzeugen,
        # nicht eine eigene Speichersektion dafür
    #Menge.difference(Vergleichsmenge) Spuckt Elemente aus, die nur in der Menge, aber nicht der Vergleichsmenge sind
        # geht auch Menge.difference(Vergleich1).difference(Vergleich2)
        # oder Menge - Vergleich1 - Vergleich2
    #Menge.difference_update(Vergleich) setzt die Menge auf den Wert, der bei differnece übrig bleibt
    #Menge.discard(Wert) löscht den Wert aus der Menge
    #Menge.remove(Wert) geht nur, wenn Wert tatsächlich Teil der Menge
    #Menge1.union(Menge2) oder Menge1|Menge2 Liefert die Vereinigung der beiden
    #Menge1.intersection(Menge2) oder Menge1&Menge2 liefert die Schnittmenge
    #Menge1.isdisjoint(Menge2) prüft, ob Schnittmenge leer ist
    #Menge1.issubset(Menge2), Menge1<Menge2 oder Menge1<=Menge2 prüft, ob Menge1 vollständig in Menge 2 enthalten ist
    #Menge1.issuperset(Menge2) prüft ob Menge1 Obermenge von Menge2 ist
    #Menge.pop() liefert ein zufälliges Element der Menge

# %% [markdown]
# ### Listen "Kopieren"
# Ein etwas "verschachteltes Thema" das wir hier erst mal nur kurz ansprechen.
# Einfach so kann man "komplizierte" listen nicht koopieren.
# https://www.python-kurs.eu/python3_deep_copy.php
#
# UM eine echte "tiefe" Kopie zu haben muss man eine Funktion namens deep Copy nutzen
#
# ![image.png](attachment:image.png)

# %%
# Echte Kopie und diese wird angepasst
from copy import deepcopy
Person1 = ["Swen", ["Seestrasse", "Konstanz"]]

# Mal mit dem "=" und Person2[0]="Sarah" testen, dann gibts nur noch Sarah
#Person2 = Person1
#Person2[0]="Sarah" #da nur Referenz wird hier die Referenz für Person2 auf einen neuen Wert gelegt
#print(Person1,Person2)

# Änderungen werden nun bei beiden Personen sichtbar
Person2 = deepcopy(Person1)
print(Person1,Person2)

# Änderungen werden nun nur bei Person2 sichtbar
Person2[0] = "Sarah" # hier mal "Sarah2" inschreiben und genau beobachten was passiert, min 2 mal ausführen!
Person2[1][0] = "Bücklestrasse"
print(Person1,Person2)
#id(Variable oder so) gibt im Prinzip die Speicherstelle für eine Variable o.ä.

# %% [markdown]
# Schaune und Üben Sie wie man mit Listen "kopieren/arbeiten" kann !

# %%
# Üben Listen Kopieren

# %% [markdown]
# ### Dictionaries
#
# Dictionaries sind eine einfache und flexible Datenstruktur in Python, die verwendet werden können, um Key-Value Paare zu speichern. Ein Key kann beliebiges Objekt sein, und ein Value kann auch beliebiges Objekt sein. Dictionaries sind nicht in einer bestimmten Reihenfolge gespeichert, sondern sind in einer Hash-Tabelle implementiert.
# Quelle https://www.python-kurs.eu/python3_dictionaries.php
#
# Hier ein kleines Beispiel:

# %%
städte_einwohner = {"Berlin": 3_669_491,
                    "Hamburg": 1_847_253,
                    "München": 1_484_226,
                    "Köln": 1_087_863,
                    "Frankfurt am Main": 763_380,
                    "Stuttgart": 635_911,
                    "Düsseldorf": 621_877,
                    "Leipzig": 593_145,
                    "Dortmund": 588_250,
                    "Essen": 582_760,
                    "Bremen": 567_559,
                    "Dresden": 556_780,
                    "Hannover": 536_925,
                    "Nürnberg": 518_370}

print(städte_einwohner["Berlin"])
print("Dortmund" in städte_einwohner)

# %% [markdown]
# Schauen und Texten Sie was mit Dictionarys geht!

# %%
#Üben Dictionary

# %% [markdown]
# ## Input
#
# Eine einfache Möglichkeit, Eingaben zu verstehen und zu verwenden, ist mit der input() Funktion. Diese Funktion liest einen String vom Benutzer ein und gibt ihn dann zurück. Man kann aber vieles damit machen oder in Sonderfälle laufen - einfach mal "schnell" reinschauen!
# Quelle: https://www.python-kurs.eu/python3_eingabe.php

# %%
#Üben mit Input z.B. mit der eval() Funktion
staedte = eval(input("Liste? "))
print(staedte)

# %% [markdown]
# ## Bedingte Anweisungen
#
# Bedingte Anweisungen sind eine einfache und übersichtliche Möglichkeit, Programme zu entwickeln, die entweder nach einer bestimmten Bedingung oder einer anderen führen. Diese Bedingungen können verschiedene "Anweisungen" enthalten, beispielsweise ein Wert aus einer Variablen Ausgeben oder eine verwerfen.
# Quelle: https://www.python-kurs.eu/python3_bedingte_anweisungen.php

# %%
person = input("Nationalität? ")
if person == "french" or person == "French":
    print("Préférez-vous parler français?")
elif person == "italian" or person == "Italian":
    print("Preferisci parlare italiano?")
else:
    print("Du bist weder Italiener noch Franzose.")
    print("Deshalb reden wir jetzt deutsch!")

# %% [markdown]
# Das Beispiel oben zeigt schon viele Optionen - können Sie English hinzufügen?
# Es gibt auch einen  Steuerrechner im Link ;-)

# %%
#Üben mit Bedingter Anweisung

# %% [markdown]
# Etwas abweichend, wenn man eher Typische Eingaben prüft und darauf reagiert ist "Case"
# https://www.python-kurs.eu/struktureller_musterabgleich.php
# Hier etwas sperrig "typischer Musterabgleich" genannt.
# Man kann hier vordefinierte Werte setzen und darauf Prüfen:

# %%
#def definiert eine Methode - praktisch, so kann man das Programmierte wieder benutzen (schon mal fast der Anfang für Objektorientierung)
def greeting(language):
    chosen_language = language.capitalize()
    match chosen_language: #Match-case macht meist in einer solchen Methode Sinn
        case 'English':
            print('Hello')
        case 'German':
            print('Hallo!')
        case _:
            print(f"Hallo, ich kenne {chosen_language} nicht")
            
greeting('english')
greeting('french')

# %% [markdown]
# ## Schleifen while und for
# Wohl eines der Wichtigsten Konzepte ist die "Wiederholung" von dingen. Wie wir oben gesehenhaben kommt man sehr schnell nicht ohne ein if oder eben eine while oder for aus. Kombiniert man dies mit Methoden (def) kann man schon schnell Modularer Programmieren und spart viel Zeit und die "richtige" Objektorienierung mit Klassen ist nur noch ein kurzer Schritt entfernt.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### While Schleife
# While Schleifen führen etwas aus, solange eine Bedingung "wahr" ist.
# Quelle: https://www.python-kurs.eu/python3_schleifen.php

# %%
n = 100

sum_of_numbers = 0
i = 1
while i <= n:
    sum_of_numbers += i
    i += 1

result = "Summe von 1 bis " + str(n) + ": " + str(sum_of_numbers)
print(result)

# %% [markdown]
# Schaut euch das Beispiel im Link an und probiert das "Ratespiel"

# %%
#Übung While "Ratespiel" und Übung 1 bis 7

# %% [markdown]
# ### for Schleife
# Wird i.d.R. genutzt wenn man über z.B. eine liste laufen oder "iterieren" möchte.
# hier hilft dann auch oft die range Funktion, schauen wir uns das mal an:
# Quelle https://www.python-kurs.eu/python3_for-schleife.php

# %%
edibles = ["ham", "spam", "eggs","nuts"]
spam = False

for food in edibles:
    if food == "spam":
        print("No more spam please!")
        spam = True
        continue
    print("Great, delicious " + food)
    # here can be the code for enjoying our food :-)
else: # das Else gehört zum FOR nicht dem if!!
    if spam:
        print("I didn't like the spam!")
    else:
        print("I am so glad: No spam!")
print("Finally, I finished stuffing myself")

# %% [markdown]
# und Range?? Hilft uns wenn wir ad hoc eine "Liste" erstellen möchten, siehe hier:

# %%
n = 100

s = 0
for counter in range(1, n+1):
    s += counter

print("Sum of 1 until " + str(n) + ": " + str(s) )

# %% [markdown]
# Und das darf man geren alles etwas Üben, unten im Link Übung 1 bis 7 gerne probieren!

# %%
#Übung mit for und co Ü1 bis Ü7

# %% [markdown]
# # Rückblick
# Das wichtigste im Schnelldurchlauf:
# * Strukturieren mit Einrücken - ist wichtig sonst geht es nicht und sieht schlecht aus!
# * Datentypen und Variablen - damit wir wissen was wir speichern!
# * Operatoren, damit wir dinge mit einander agieren lassen können
# * Listen, Mengen, Dictionaries - wenn vieles zusammenkommen soll!
# * Input von Aussen
# * Bedingungen stellen und das eine oder andere in reaktion tun!
# * Wiederholen lassen, statt selbst immer wieder hin zu schreiben (da helfen auch Funktionen/Methoden mit def)

# %% [markdown]
# # Ausblick
# Es gibt noch viele Details die man sich anschauen kann, dies machen wir dann Ad Hoc oder wenn Sie mögen gerne einfach weiter im Kurs schauen!
# Wir werden als nächstes:
# * Einen Blick auf Funktionen/Methoden werfen https://www.python-kurs.eu/python3_funktionen.php
# * Dateien Lesen und Schreiben https://www.python-kurs.eu/python3_dateien.php
# * Kurzblick auch OOP (Objekte, Klassen und Methoden) https://www.python-kurs.eu/einfuehrung_objektorientierte_programmierung_unter_python.php
# * KI relevante Bibliotheken numpy scikit und pandas (https://www.python-kurs.eu/numerisches_programmieren_in_Python.php)
